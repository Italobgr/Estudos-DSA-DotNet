# %% [markdown]
# # Exercícios Práticos: Desafios Iniciais
#
# Aqui estão alguns exercícios práticos baseados nos desafios mais famosos. Tente resolvê-los em C#! Abaixo de cada explicação existe uma célula de código em branco para você testar sua implementação.

# %% [markdown]
# ## Exercício 1: O Clássico FizzBuzz
# Escreva um método que receba um número inteiro `n` e imprima os números de 1 a `n` seguindo a regra do FizzBuzz.
#
# **Regras:**
# - Múltiplos de 3 -> "Fizz"
# - Múltiplos de 5 -> "Buzz"
# - Múltiplos de ambos (3 e 5) -> "FizzBuzz"
# - Caso contrário -> imprima o próprio número
#
# Escreva a função e chame-a testando com `n = 15`.

# %%
public void ImprimirFizzBuzz(int n)
{
    // Sua implementação aqui
}

ImprimirFizzBuzz(15);

# %% [markdown]
# ## Exercício 2: Two Sum (Soma de Dois)
# Dado um array de inteiros `nums` e um inteiro `target`, retorne os índices dos dois números cuja soma seja igual a `target`.
# Tente resolver com complexidade de tempo `O(n)` usando um `Dictionary`.
#
# **Exemplo:**
# - Entrada: `nums = [2, 7, 11, 15]`, `target = 9`
# - Saída: `[0, 1]`

# %%
public int[] TwoSum(int[] nums, int target)
{
    // Sua implementação aqui
    return new int[0];
}

int[] resultado = TwoSum(new int[] { 2, 7, 11, 15 }, 9);
// Console.WriteLine($"[{resultado[0]}, {resultado[1]}]"); // Descomente para testar

# %% [markdown]
# ## Exercício 3: Palíndromo Válido
# Escreva uma função que receba uma string e retorne `true` se ela for um palíndromo e `false` caso contrário. A função deve ignorar espaços e não fazer distinção entre letras maiúsculas e minúsculas.
#
# **Exemplo:**
# - Entrada: `"A base do teto desaba"`
# - Saída: `true`

# %%
public bool EhPalindromo(string texto)
{
    // Sua implementação aqui
    return false;
}

Console.WriteLine(EhPalindromo("A base do teto desaba"));

# %% [markdown]
# ## Exercício 4: N-ésimo Fibonacci
# Implemente um método que retorne o N-ésimo número da sequência de Fibonacci. Tente implementar a versão iterativa (com `for` ou `while`).
#
# **Exemplo:**
# - Entrada: `n = 5`
# - Saída: `5` (Sequência: 0, 1, 1, 2, 3, 5)

# %%
public int CalcularFibonacci(int n)
{
    // Sua implementação aqui
    return 0;
}

Console.WriteLine(CalcularFibonacci(5));

# %% [markdown]
# ## Exercício 5: Validador de Anagramas
# Crie um método que receba duas strings e determine se uma é um anagrama da outra.
#
# **Exemplo:**
# - Entrada 1: `"listen"`, Entrada 2: `"silent"`
# - Saída: `true`

# %%
public bool EhAnagrama(string s, string t)
{
    // Sua implementação aqui
    return false;
}

Console.WriteLine(EhAnagrama("listen", "silent"));
